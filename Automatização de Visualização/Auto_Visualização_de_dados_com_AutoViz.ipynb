# %% [markdown]
# # Auto Visualização de dados
# Uma das principais etapas de um projeto de machine learning é a Análise exploratória e dentro dela há a visualização dos dados de forma gráfica e para isso utiliza-se diversas bibliotecas de visualização de dados como o Plotly, Matplotlib, Seaborn, Bokeh e até Pandas ou outras ferramentas de visualização mais específicas, como Power BI, Tableau e Qlik Sense dentre outras.
#
# Muitas vezes esse processo pode ser um pouco demorado, principalmente por exige, além do conhecimento básico em programação em python, o conhecimento das funções de cada uma dessas bibliotecas antes citadas. Como essa etapa gráfica é, geralmente, curta e serve para responder certas hipóteses levantadas no início do projeto e/ou extrair insights, seria uma alternativa automatizar esse processo.
#
# Para isso há duas bibliotecas de auto visualização chamadas autoviz e sweetviz que usarei rapidamente nesse notebook.
#
# Para instalar essas bibliotecas usei o comando pip install autoviz e pip install sweetviz e abaixo estarei importando e instanciando o módulo de auto visualização. Veja que nem a biblioteca pandas foi necessário importar.

# %% [markdown]
# # Dados
# A base utilizada pode ser obtida [aqui](https://www.kaggle.com/datasets/adityadesai13/used-car-dataset-ford-and-mercedes) e trata de um conjunto de carros da marca FORD (cerca de 17966 observações) e suas características (nove colunas).

# %%
# !pip install autoviz

# %%
# !pip install sweetviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 86.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Importando e instanciando a AutoViz
#
# ![image.png](data:image/png;base64,...)

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
# %matplotlib inline

# %% [markdown]
# Agora basta aplicar a biblioteca definindo a base de dados e a variável target.
#
# Abaixo a biblioteca já realiza um pequeno relatório da base de dados com suas dimensões, quais os tipos de dados e quais são os preditores.

# %%
AV.AutoViz('/content/drive/MyDrive/AutoML/Auto_pycaret/ford.csv',depVar='price')
# Out:
# Shape of your Data Set loaded: (17965, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# Data cleaning improvement suggestions. Complete them before proceeding to ML modeling.
# <style type="text/css">
# #T_469af_row0_col0, #T_469af_row0_col4, #T_469af_row7_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_469af_row0_col1, #T_469af_row0_col6, #T_469af_row1_col1, #T_469af_row1_col6, #T_469af_row2_col1, #T_469af_row2_col6, #T_469af_row3_col1, #T_469af_row3_col6, #T_469af_row4_col1, #T_469af_row4_col6, #T_469af_row5_col1, #T_469af_row5_col6, #T_469af_row6_col1, #T_469af_row6_col6, #T_469af_row7_col1, #T_469af_row7_col6 {
#   font-family: Segoe UI;
# }
# ...

# %% [markdown]
# Acima pode ser ver que forma gerados:
#
# 1. Relação gráfica por meio de uma scatterplot (gráfico de dispersão) das variáveis contínuas em relação a variável target. Podemos ver que não há uma relação entre price e mpg, mas entre engineSize e price há, pois a medida que a engineSize aumenta o preço também é maior;
#
# 2. Pairwise-plot de todas as variáveis;
#
# 3. Histograma (distribuição dos dados), Boxplots, QQplot e Violinplot de todas as variáveis contínuas. Aqui vemos que as variáveis contínuas não possuem uma distribuição normal, o que pode ser um problema na hora de passá-las para modelos de machine learning ou de deep learning, pois alguns desses modelos pressupõem normalidade nas variáveis. Isso mostra que essas colunas precisam de algum tipo de tratamento (normalização ou padronização). Outra coisa que pode-se notar é a presença de muitos outliers na variável price que pode ser ruim para o treinamento de um modelo, então essa coluna pode requerer um tratamento;
#
# 4. Heatmap (Mapa de calor) mostrando a correlação entre as variáveis. Podemos identificar quais as features mais adequadas para ser usadas em algum modelo;
#
# 5. Pivot Table mostrando a relação da variável target com mais de uma feature categóricas;
#
# 6. Gráficos de barras (barplots) para ver quais as relações médias entre várias outras variáveis e nossa variável alvo;
#
# 7. Por último, a base de dados completa e suas colunas.

# %% [markdown]
# # Trabalhando com a SweetViz

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Este pacote gera visualizações também com apenas uma linha, produzindo um arquivo HTML totalmente independente, ela apresenta um ótimo diferencial , a possibilidade de comparação entre datasets.
#
# Na [documentação oficial](https://pypi.org/project/sweetviz/) é apresentado como exemplo a utilização na famosa base de dados do Titanic, que com certeza você já utilizou quando estava aprendendo machine learning.

# %% [markdown]
# O código para gerar o relatório é muito simples também :

# %%
import sweetviz as sv
import pandas as pd

ford =pd.read_csv("/content/drive/MyDrive/AutoML/Auto_pycaret/ford.csv")

ford.head(10)
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5   Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6     Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7   Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8     Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9    Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0

# %%
my_report = sv.analyze(ford)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# A saída da biblioteca sweetviz é um arquivo html. Precisamos fornecer um nome de arquivo com a tag html na função show_html.

# %%
my_report.show_html('ford_report_EDA.html')
# Out:
# Report ford_report_EDA.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# O relatório gerado fica da seguinte forma:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Conclusão
# O único objetivo desse projeto é apresentar essas bibliotecas que dependendo do analista pode ser ou não útil para identificar padrões nos dados e extrair insghts. Acredito, particularmente, que com a finalidade de otimizar o tempo e linhas de código essas ferramentas podme ser bem vindas para realizar análise rapidas.
